# %% [markdown]
# # Probability Solutions

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
# -Keep track of the number of times that the sum was either greater than 7 or even
# -Divide the number from step 2 by the number of iterations (1000)

# %%
import random
import numpy as np

#Funtion to roll the dice.

def roll_the_dice(n_simulations = 1000):
    count = 0
    
    #each iteration of the for loop is trial
    for i in range(n_simulations):
        
        #roll each die
        die1 = random.randint(1,6)
        die2 = random.randint(1,6)
        
        #Sum the values to get the score
        score = die1 + die2
        
        #decide if we should add it to the count:
        if score % 2 == 0 or score > 7 :
            count+= 1
    
    return count/n_simulations
string = 'The probability of rolling an even number or greater than 7 is:'

print(string, np.round(roll_the_dice()*100, 2), '%')
# Out:
# The probability of rolling an even number or greater than 7 is: 69.2 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color. Below is code to do that.

# %%
import numpy as np

d = {}

for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'
        
#Initialize important variables
n_simulations = 1000
part_a_total = 0 
part_b_total = 0

for i in range(n_simulations):
    
    #make a list of the colors that we choose
    list = []
    
    for i in range(5):
        list.append(d[random.randint(0,59)])
        
    #Convert it to a numpy array
    list = np.array(list)

    #find the number of each taht we picked
    white = sum(list == 'White')
    red = sum(list == 'Red')
    green = sum(list == 'Green')

    #Keep track if the combination met the criteria
    if white == 3 and red == 2:
        part_a_total += 1
    
    if red == 5 or white == 5 or green ==5:
        part_b_total +=1

print('The probability of 3 white and 2 red is:', round(part_a_total/n_simulations*100,2),'%')
print('The probability of all the same color is:', round(part_b_total/n_simulations*100,2),'%')
# Out:
# The probability of 3 white and 2 red is: 1.0999999999999999 %
# The probability of all the same color is: 3.3000000000000003 %
